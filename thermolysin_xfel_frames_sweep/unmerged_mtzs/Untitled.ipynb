# %%
import reciprocalspaceship as rs
import numpy as np

# %%
unmerged_minus = rs.read_mtz("friedel_minus.mtz")
unmerged_plus = rs.read_mtz("friedel_plus.mtz")
max_batch = max(unmerged["BATCH"])
for n_imgs in np.linspace((max_batch+1)/8,max_batch+1,8):
    n_imgs = int(n_imgs)
    um = unmerged_minus.loc[unmerged_minus["BATCH"]<n_imgs,:]
    um.write_mtz(f"friedel_minus_n{n_imgs}.mtz")
    up = unmerged_plus.loc[unmerged_plus["BATCH"]<n_imgs,:]
    up.write_mtz(f"friedel_plus_n{n_imgs}.mtz")
# Out:
# /net/holy-nfsisilon/ifs/rc_labs/hekstra_lab/people/hwang/anaconda/envs/laue/lib/python3.11/site-packages/reciprocalspaceship/dataset.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[key] = dataset[key].astype(dtype)
# /net/holy-nfsisilon/ifs/rc_labs/hekstra_lab/people/hwang/anaconda/envs/laue/lib/python3.11/site-packages/reciprocalspaceship/dataset.py:1266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[["H", "K", "L"]] = asu_hkls[inverse]
# ...
